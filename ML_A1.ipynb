# %% [markdown]
# <a href="https://colab.research.google.com/github/saivenkat2309/ML_A1/blob/main/ML_A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/sample_data/D3.csv')
X1 = df.values[:,0]
X2 = df.values[:,1]
X3 = df.values[:,2]
Y = df.values[:,3]

# Plot of X1
plt.scatter(X1, Y, color='black',marker='+')
plt.grid(True)
plt.rcParams["figure.figsize"] = (6, 6)
plt.xlabel('plot X1')
plt.ylabel('plot y')
plt.title('model graph')

plt.show()

# Plot of X2
plt.scatter(X2, Y, color='black',marker='+')
plt.grid(True)
plt.rcParams["figure.figsize"] = (6, 6)
plt.xlabel('plot X2')
plt.ylabel('plot y')
plt.title('model graph')

plt.show()

# Plot of X3
plt.scatter(X1, Y, color='black',marker='+')
plt.grid(True)
plt.rcParams["figure.figsize"] = (6, 6)
plt.xlabel('plot X3')
plt.ylabel('plot y')
plt.title('model graph')

plt.show()

# %%
m = len(X1) #dimension of data column
X0 = np.ones((m,1)) #creates X0 filled with 1s
X1 = X1.reshape(m,1) #transposes explanatory columns
X2 = X2.reshape(m,1)
X3 = X3.reshape(m,1)
Y = Y.reshape(m,1)

# %%
def compute_cost(X, y, theta):

    predictions = X.dot(theta)
    errors = np.subtract(predictions, y)
    sqrErrors = np.square(errors)
    J = 1 / (2 * m) * np.sum(sqrErrors)
    return J

def gradient_descent(X, y, theta, alpha, iterations):

    m = len(y)  # Number of training examples
    cost_history = np.zeros(iterations)
    for i in range(iterations):
        predictions = X.dot(theta)
        errors = np.subtract(predictions, y)
        sum_delta = (alpha / m) * X.transpose().dot(errors)
        theta -= sum_delta
        cost_history[i] = compute_cost(X, y, theta)

    return theta, cost_history

# %%
iterations = 3500
alpha = 0.01
X = np.column_stack((X0, X1))
theta = np.zeros((2, 1))
theta, loss_history = gradient_descent(X, Y, theta, alpha, iterations)
print('Theta for X1:', theta[1])
print('Theta for X0 (bias):', theta[0])
# Out:
# Theta for X1: [-2.03737191]
# Theta for X0 (bias): [5.92547022]

# %%
plt.scatter(X1, Y, label='Data Points')
plt.plot(X1, X @ theta, color='black', label='Linear Regression')
plt.xlabel('X1')
plt.ylabel('Y')
plt.title('Regression of X1')
plt.legend()

# %%
plt.plot(range(iterations), loss_history, label='Loss')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('X1 Loss')
plt.legend()

# %%
iterations = 1800
alpha = 0.08
X = np.column_stack((X0, X2))
theta = np.zeros((2, 1))
theta, loss_history = gradient_descent(X, Y, theta, alpha, iterations)
print('Theta for X2:', theta[1])
print('Theta for X0 (bias):', theta[0])
# Out:
# Theta for X2: [0.55760761]
# Theta for X0 (bias): [0.73606043]

# %%
plt.scatter(X2, Y, label='Data')
plt.plot(X2, X.dot(theta), color='black', label='Linear Regression')
plt.xlabel('X2 Data Input')
plt.ylabel('Output (Y)')
plt.title('Regression of X2')
plt.legend()

# %%
plt.plot(range(1, iterations + 1), loss_history, label='Loss History')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('X2 Loss')
plt.grid(True)
plt.legend()

# %%
iterations = 3100
alpha = 0.01
X = np.hstack((X0,X3))
theta = np.zeros((2,1))
theta, loss_history = gradient_descent(X, Y, theta, alpha, iterations)
print('Theta for X3:', theta[1])
print('Theta for X0 (bias):', theta[0])
# Out:
# Theta for X3: [-0.51950147]
# Theta for X0 (bias): [2.86894061]

# %%
plt.scatter(X3, Y)
plt.plot(X3, X.dot(theta), color = 'brown', label = 'Linear Regression Fit')
plt.xlabel('X3 Data Input')
plt.ylabel('Y Data Output')
plt.title('Regression of X3')
plt.legend()
plt.show()

# %%
plt.plot(range(1, iterations + 1), loss_history, color='black')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Loss X3')
plt.show()

# %%
iterations = 5000
alpha = 0.01
X = np.hstack((X0,X1,X2,X3))
theta = np.ones((4,1)) * 0.5

theta, loss_history = gradient_descent(X, Y, theta, alpha, iterations)
print('Final theta for X_ALL:', theta)
print('Final loss:', loss_history[-1])
# Out:
# Final theta for X_ALL: [[ 5.28046548]
#  [-1.99895835]
#  [ 0.53813233]
#  [-0.26066188]]
# Final loss: 0.738524743608434

# %%
plt.plot(range(1, iterations + 1), loss_history, color='black', marker='+', markersize=2)
plt.grid(linestyle='--')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('X_all Loss, alpha = 0.01')
plt.tight_layout()
X_test = np.array([[1,1,1,1], [1,2,0,4], [1,3,2,1]])
predictions = X_test.dot(theta)

for i, prediction in enumerate(predictions):
  print(f'Prediction {i+1} ({X_test[i,1:]}) = {prediction}')
# Out:
# Prediction 1 ([1 1 1]) = [3.55897758]
# Prediction 2 ([2 0 4]) = [0.23990126]
# Prediction 3 ([3 2 1]) = [0.09919322]

# %%
iterations = 4200
alpha = 0.1
X = np.hstack((X0,X1,X2,X3))
theta = np.ones((4,1)) * 0.5

theta, loss_history = gradient_descent(X, Y, theta, alpha, iterations)
print('Final theta for X_ALL:', theta)
print('Final loss:', loss_history[-1])
# Out:
# Final theta for X_ALL: [[ 5.31416717]
#  [-2.00371927]
#  [ 0.53256334]
#  [-0.26560187]]
# Final loss: 0.7384642415682942

# %%
plt.plot(range(1, iterations + 1), loss_history, color='brown', marker='+', markersize=2)
plt.grid(linestyle='--')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('X_all Loss, alpha = 0.1')
plt.tight_layout()
X_test = np.array([[1,1,1,1], [1,2,0,4], [1,3,2,1]])
predictions = X_test.dot(theta)
